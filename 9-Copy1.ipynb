# %%
import pandas as pd
# %matplotlib inline

df3 = pd.read_csv('df3.csv')
print(len(df3))
print(df3.head())
# Out:
# 500
#        weekday  produced  defective
# 0     1.Monday        73          7
# 1    2.Tuesday        75         10
# 2  3.Wednesday        86          7
# 3   4.Thursday        64          7
# 4     5.Friday        70          6

# %%
df3.defective
# Out:
# 0       7
# 1      10
# 2       7
# 3       7
# 4       6
#        ..
# 495     8
# 496    10
# 497     7
# 498     6
# 499     5
# Name: defective, Length: 500, dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(12,3))
plt.scatter(df3.produced, df3.defective, c = 'green', s=20)
plt.xlabel("produced")
plt.ylabel("defective")
# Out:
# Text(0, 0.5, 'defective')

# %%
plt.hist(df3.produced)
plt.ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %%
plt.hist(df3.produced, edgecolor='black', range=[55, 95]) 
plt.ylabel("Frequency")
plt.xlim([55, 95])
# Out:
# (55.0, 95.0)

# %%
df3.boxplot(column='produced',by='weekday',grid=False)
# Out:
# <AxesSubplot:title={'center':'produced'}, xlabel='weekday'>

# %%
import numpy as np

# %%
df3.defective.plot.kde()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14620/3068535801.py in <module>
# ----> 1 df3.defective.plot.kde()
#
# NameError: name 'df3' is not defined

# %%
df_new = df3.loc[:30,['defective','produced']]
df_new
# Out:
#     defective  produced
# 0           7        73
# 1          10        75
# 2           7        86
# 3           7        64
# 4           6        70
# 5           9        80
# 6           9        89
# 7           6        72
# 8           7        72
# 9           5        66
# 10          9        79
# 11         10        77
# 12          8        67
# 13          7        66
# 14          5        68
# 15          8        79
# 16         10        74
# 17          6        87
# 18          5        72
# 19          6        60
# 20          9        62
# 21         10        91
# 22          6        87
# 23          5        69
# 24          5        75
# 25          8        77
# 26          9        83
# 27          6        70
# 28          5        61
# 29          6        72
# 30          8        81

# %%
df_new.plot.area(alpha=0.5, color = ['k','#d62728'])
# Out:
# <AxesSubplot:>

# %%
df_new.plot.area(alpha=0.5, color = ['k','#d62728'])
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
